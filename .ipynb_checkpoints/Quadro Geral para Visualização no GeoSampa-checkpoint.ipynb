# %% [markdown]
# # Quadro geral para visualização no GeoSampa
#
# Esse aqui é o NoteBook Para Planejamento da Visualização dos dados no GeoSampa

# %%
import pandas as pd
import glob

# Abrindo o ano de 2020
df = pd.read_csv('download/dados-do-sp156---1o-sem-2020.zip',index_col=None, header=0, encoding="ISO-8859-1", delimiter=';', parse_dates=['Data de abertura', 'Data do parecer'])
# Out:
# /home/fernando/miniconda3/envs/geopandas/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_3tri = pd.read_csv('download/dados-do-sp156---3o-tri-2020.csv',index_col=None, header=0, encoding="UTF-8", delimiter=',', parse_dates=['Data de abertura', 'Data do parecer'])

# %%
df = pd.concat([df, df_3tri])
# df_3tri

# %%
df.reset_index(inplace=True)

# %%
df['Latitude'] = pd.to_numeric(df['Latitude'].str.replace(',', '.'), errors='coerce')
df['Longitude'] = pd.to_numeric(df['Longitude'].str.replace(',', '.'), errors='coerce')

# %%
df.dtypes
# Out:
# index                             int64
# Data de abertura         datetime64[ns]
# Canal                            object
# Tema                             object
# Assunto                          object
# Serviço                          object
# Logradouro                       object
# Número                          float64
# CEP                              object
# Subprefeitura                    object
# Distrito                         object
# Setor                           float64
# Quadra                          float64
# Latitude                        float64
# Longitude                       float64
# Data do parecer          datetime64[ns]
# Status da solicitação            object
# Órgão                            object
# dtype: object

# %% [markdown]
# ## Criando arquivo de LOG do processamento
#
# Esse arquivo de log vai seguir documentando o processamento para servir de apêndice ao metadado

# %%
import os
if os.path.exists("./logs/log-visualizacao-sp156-2020.txt"):
    os.remove("./logs/log-visualizacao-sp156-2020.txt")

# %%
log = open("./logs/log-visualizacao-sp156-2020.txt", "w+")

# %%
from datetime import datetime
now = datetime.now()

# %%
log.write(f'## Iniciando o processamento da espacialização dos Atentimentos do SP 156\n')
log.write(f'- {datetime.now().strftime("%d/%m/%Y %H:%M:%S")}\n')
# Out:
# 22

# %% [markdown]
# ## Suprimindo da visualização serviços pouco solicitados
#
# Para melhorar a navagação seria interessante ter menos serviços dessa forma podemos criar um grupo grande com outros serviços

# %%
log.write('## Removendo serviços com menos de 200 ocorrências\n')
# Out:
# 51

# %%
limite = 200

# %%
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
log.write('- Documentando serviços que ficarão de fora da visualização\n')
log.write(f'- salvando o resultado em ./resultados/hierarquia-de-visualizacao-abaixo-limite-{limite}.csv\n')
# Out:
# 88

# %%
df[~df.Distrito.isna()].groupby(['Serviço']).filter(lambda x: len(x) > limite).groupby(['Tema','Serviço'])['Canal'].count().to_csv(f'./resultados/hierarquia-de-visualizacao-limite-{limite}.csv')

# %%
log.write('- Documentando serviços com mais de 200 ocorrências visualização\n')
log.write(f'- salvando o resultado em ./resultados/hierarquia-de-visualizacao-limite-{limite}.csv\n')
# Out:
# 81

# %%
df[~df.Distrito.isna()].groupby(['Serviço']).filter(lambda x: len(x) <= limite).groupby(['Tema','Serviço'])['Canal'].count().to_csv(f'./resultados/hierarquia-de-visualizacao-abaixo-limite-{limite}.csv')

# %%
df_menor_200 = df.drop(df.groupby(['Serviço']).filter(lambda x: len(x) > limite).index)

# %%
df = df.drop(df.groupby(['Serviço']).filter(lambda x: len(x) <= limite).index)

# %%
df
# Out:
#           index        Data de abertura  \
# 0             0 2020-01-01 00:00:15.000
# 1             1 2020-01-01 00:01:18.000
# 2             2 2020-01-01 00:04:13.000
# 3             3 2020-01-01 00:06:57.000
# 4             4 2020-01-01 00:08:05.000
# ...         ...                     ...
# 1019460  354480 2020-10-01 02:56:22.565
# 1019461  354481 2020-10-01 02:57:28.485
# 1019462  354482 2020-10-01 02:57:29.197
# 1019463  354483 2020-10-01 02:58:00.813
# 1019464  354484 2020-10-01 02:58:08.959
#
#                                             Canal  \
# 0                                   PORTAL ONLINE
# 1                                      APLICATIVO
# 2                                      APLICATIVO
# 3                                      APLICATIVO
# 4                              CENTRAL TELEFÔNICA
# ...                                           ...
# 1019460                        CENTRAL TELEFÔNICA
# 1019461  PRAÇAS DE ATENDIMENTO DAS SUBPREFEITURAS
# 1019462                        CENTRAL TELEFÔNICA
# 1019463                        CENTRAL TELEFÔNICA
# 1019464                        CENTRAL TELEFÔNICA
#
#                                    Tema  \
# 0                          Rua e bairro
# 1                          Rua e bairro
# 2                          Rua e bairro
# 3                          Rua e bairro
# 4                 Trânsito e Transporte
# ...                                 ...
# 1019460                    Rua e bairro
# 1019461           Trânsito e Transporte
# 1019462  Cidadania e assistência social
# 1019463                        Urgência
# 1019464                        Urgência
#
#                                         Assunto  \
# 0                        Poluição Sonora - PSIU
# 1         Reparos em asfalto, pontes e viadutos
# 2         Reparos em asfalto, pontes e viadutos
# 3         Reparos em asfalto, pontes e viadutos
# 4                             Reclamação ônibus
# ...                                         ...
# 1019460                  Poluição Sonora - PSIU
# 1019461              Estacionamento e Zona Azul
# 1019462  População ou pessoa em situação de rua
# 1019463              Guarda Civil Metropolitana
# 1019464              Guarda Civil Metropolitana
#
#                                                    Serviço  \
# 0                     Reclamação de poluição sonora - PSIU
# 1                                              Tapa-buraco
# 2                                              Tapa-buraco
# 3                                              Tapa-buraco
# 4        Ônibus - Reclamação de intervalo excessivo da ...
# ...                                                    ...
# 1019460               Reclamação de poluição sonora - PSIU
# 1019461  Cartão de estacionamento DeFis (pessoa com def...
# 1019462  Serviço Especializado de Abordagem Social às P...
# 1019463                             Perturbação do sossego
# 1019464                             Perturbação do sossego
#
#                                    Logradouro  Número          CEP  \
# 0                                         NaN     NaN          NaN
# 1        Rua Doutor Paulo Furtado de Oliveira   401.0  2.67403e+06
# 2        Rua Doutor Paulo Furtado de Oliveira   341.0  2.67403e+06
# 3        Rua Doutor Paulo Furtado de Oliveira   250.0  2.67403e+06
# 4                                 Rua Kotinda  1679.0  2.36501e+06
# ...                                       ...     ...          ...
# 1019460                                   NaN     NaN          NaN
# 1019461                                   NaN     NaN          NaN
# 1019462                                   NaN     NaN          NaN
# 1019463                                   NaN     NaN          NaN
# 1019464                                   NaN     NaN          NaN
#
#                    Subprefeitura      Distrito  Setor  Quadra   Latitude  \
# 0               SANTANA-TUCURUVI       SANTANA    NaN     NaN        NaN
# 1        CASA VERDE-CACHOEIRINHA  CACHOEIRINHA  108.0    89.0 -23.459489
# 2        CASA VERDE-CACHOEIRINHA  CACHOEIRINHA  108.0    89.0 -23.459793
# 3        CASA VERDE-CACHOEIRINHA  CACHOEIRINHA  108.0    81.0 -23.460395
# 4                JACANA-TREMEMBE      TREMEMBE    NaN     NaN -23.425205
# ...                          ...           ...    ...     ...        ...
# 1019460                    MOOCA     AGUA RASA    NaN     NaN        NaN
# 1019461                      NaN           NaN    NaN     NaN        NaN
# 1019462              SANTO AMARO   SANTO AMARO    NaN     NaN        NaN
# 1019463                       SE    BELA VISTA    NaN     NaN        NaN
# 1019464          JACANA-TREMEMBE      TREMEMBE    NaN     NaN        NaN
#
#          Longitude         Data do parecer   Status da solicitação    Órgão
# 0              NaN                     NaT  AGUARDANDO ATENDIMENTO    SMSUB
# 1       -46.667533 2020-01-04 20:35:15.000              FINALIZADA    SMSUB
# 2       -46.668002 2020-01-04 20:36:10.000              FINALIZADA    SMSUB
# 3       -46.668632 2020-01-04 20:38:05.000              FINALIZADA    SMSUB
# 4       -46.582186 2020-02-08 06:11:29.000              FINALIZADA  SPTRANS
# ...            ...                     ...                     ...      ...
# 1019460        NaN                     NaT  AGUARDANDO ATENDIMENTO    SMSUB
# 1019461        NaN 2020-10-01 11:55:51.264              INDEFERIDO  SMT-DSV
# 1019462        NaN 2020-10-01 04:32:55.574              FINALIZADA    SMADS
# 1019463        NaN 2020-10-01 03:07:55.000              FINALIZADA      GCM
# 1019464        NaN 2020-10-01 03:16:00.000              FINALIZADA      GCM
#
# [1001968 rows x 18 columns]

# %%
df[df.Serviço.str.contains('morcego')]
# Out:
#           index        Data de abertura               Canal     Tema  \
# 105         105 2020-01-01 04:31:31.000  CENTRAL TELEFÔNICA  Animais
# 495         495 2020-01-01 16:31:01.000  CENTRAL TELEFÔNICA  Animais
# 727         727 2020-01-01 19:21:07.000  CENTRAL TELEFÔNICA  Animais
# 910         910 2020-01-01 21:49:34.000  CENTRAL TELEFÔNICA  Animais
# 1509       1509 2020-01-02 10:31:12.000  CENTRAL TELEFÔNICA  Animais
# ...         ...                     ...                 ...      ...
# 1011796  346816 2020-09-29 18:26:54.183  CENTRAL TELEFÔNICA  Animais
# 1014109  349129 2020-09-30 09:10:38.071  CENTRAL TELEFÔNICA  Animais
# 1014370  349390 2020-09-30 11:28:08.265  CENTRAL TELEFÔNICA  Animais
# 1015081  350101 2020-09-30 13:26:30.816  CENTRAL TELEFÔNICA  Animais
# 1015332  350352 2020-09-30 13:56:42.517  CENTRAL TELEFÔNICA  Animais
#
#                                                    Assunto  \
# 105      Animais que podem causar doenças e/ou agravos ...
# 495      Animais que podem causar doenças e/ou agravos ...
# 727      Animais que podem causar doenças e/ou agravos ...
# 910      Animais que podem causar doenças e/ou agravos ...
# 1509     Animais que podem causar doenças e/ou agravos ...
# ...                                                    ...
# 1011796  Animais que podem causar doenças e/ou agravos ...
# 1014109  Animais que podem causar doenças e/ou agravos ...
# 1014370  Animais que podem causar doenças e/ou agravos ...
# 1015081  Animais que podem causar doenças e/ou agravos ...
# 1015332  Animais que podem causar doenças e/ou agravos ...
#
#                                             Serviço  \
# 105      Morcego - Reclamar sobre local com morcego
# 495      Morcego - Reclamar sobre local com morcego
# 727      Morcego - Reclamar sobre local com morcego
# 910      Morcego - Reclamar sobre local com morcego
# 1509     Morcego - Reclamar sobre local com morcego
# ...                                             ...
# 1011796  Morcego - Reclamar sobre local com morcego
# 1014109  Morcego - Reclamar sobre local com morcego
# 1014370  Morcego - Reclamar sobre local com morcego
# 1015081  Morcego - Reclamar sobre local com morcego
# 1015332  Morcego - Reclamar sobre local com morcego
#
#                            Logradouro  Número  CEP  Subprefeitura  \
# 105                        Rua Cotoxó     NaN  NaN           LAPA
# 495              Rua Hónorato Pereira     NaN  NaN          PERUS
# 727                     Rua Andaquara     NaN  NaN    SANTO AMARO
# 910                     Rua São Paulo     NaN  NaN  VILA PRUDENTE
# 1509          Rua Antero Mendes Leite     NaN  NaN   VILA MARIANA
# ...                               ...     ...  ...            ...
# 1011796               Rua Maria Stela     NaN  NaN    M'BOI MIRIM
# 1014109                  Rua Michigan     NaN  NaN      PINHEIROS
# 1014370       Rua Dona Maria Quitéria     NaN  NaN       IPIRANGA
# 1015081  Rua Arquiteto Heitor de Melo     NaN  NaN          PENHA
# 1015332            Rua Estados Unidos     NaN  NaN      PINHEIROS
#
#                 Distrito  Setor  Quadra  Latitude  Longitude  \
# 105             PERDIZES   12.0    50.0       NaN        NaN
# 495           ANHANGUERA  203.0    19.0       NaN        NaN
# 727         CAMPO GRANDE   88.0   300.0       NaN        NaN
# 910            SAO LUCAS  156.0    37.0       NaN        NaN
# 1509        VILA MARIANA   38.0    61.0       NaN        NaN
# ...                  ...    ...     ...       ...        ...
# 1011796  JARDIM SAO LUIS   94.0   258.0       NaN        NaN
# 1014109       ITAIM BIBI   85.0   550.0       NaN        NaN
# 1014370         IPIRANGA   43.0   126.0       NaN        NaN
# 1015081     VILA MATILDE   57.0   174.0       NaN        NaN
# 1015332  JARDIM PAULISTA   14.0    94.0       NaN        NaN
#
#                 Data do parecer Status da solicitação           Órgão
# 105     2020-01-01 15:48:30.000            FINALIZADA  SMS-COVISA-DVZ
# 495     2020-01-01 19:39:33.000            FINALIZADA  SMS-COVISA-DVZ
# 727     2020-01-06 09:57:01.000            FINALIZADA  SMS-COVISA-DVZ
# 910     2020-01-06 09:54:14.000            FINALIZADA  SMS-COVISA-DVZ
# 1509    2020-01-06 11:17:39.000            FINALIZADA  SMS-COVISA-DVZ
# ...                         ...                   ...             ...
# 1011796 2020-10-08 12:06:39.399            FINALIZADA      COVISA-DVZ
# 1014109 2020-09-30 16:25:25.382            FINALIZADA      COVISA-DVZ
# 1014370 2020-09-30 16:27:18.560            FINALIZADA      COVISA-DVZ
# 1015081 2020-10-01 14:15:39.380            FINALIZADA      COVISA-DVZ
# 1015332 2020-10-01 11:24:36.682            FINALIZADA      COVISA-DVZ
#
# [1115 rows x 18 columns]

# %% [markdown]
# ## Pontos
#
# No caso dos pontos podemos gerar um arquivo sem discretização, ou seja, cada registro conterá seu ponto.
#
# Então para todos os registros vamos criar uma geometria de pontos pela Lat e Long

# %%
import geopandas as gpd

# %%
log.write(f'## Convertendo Lat/Long (epsg:4989) em UTM SIRGAS 2000 (epsg:31983)\n')
# Out:
# 68

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))
gdf_menor_200 = gpd.GeoDataFrame(df_menor_200, geometry=gpd.points_from_xy(df_menor_200.Longitude, df_menor_200.Latitude))

# %%
gdf.crs = 'epsg:4989'
gdf = gdf.to_crs('epsg:31983')
gdf_menor_200.crs = 'epsg:4989'
gdf_menor_200 = gdf_menor_200.to_crs('epsg:31983')

# %%
gdf[gdf.geometry.is_valid]
# Out:
#          index    Data de abertura               Canal                   Tema  \
# 1            1 2020-01-01 00:01:18          APLICATIVO           Rua e bairro
# 2            2 2020-01-01 00:04:13          APLICATIVO           Rua e bairro
# 3            3 2020-01-01 00:06:57          APLICATIVO           Rua e bairro
# 4            4 2020-01-01 00:08:05  CENTRAL TELEFÔNICA  Trânsito e Transporte
# 5            5 2020-01-01 00:09:19          APLICATIVO           Rua e bairro
# ...        ...                 ...                 ...                    ...
# 664938  664938 2020-06-30 23:20:16       PORTAL ONLINE         Lixo e limpeza
# 664942  664942 2020-06-30 23:22:10       PORTAL ONLINE           Rua e bairro
# 664969  664969 2020-06-30 23:46:19          APLICATIVO         Lixo e limpeza
# 664970  664970 2020-06-30 23:54:09          APLICATIVO         Lixo e limpeza
# 664972  664972 2020-06-30 23:56:28          APLICATIVO           Rua e bairro
#
#                                       Assunto  \
# 1       Reparos em asfalto, pontes e viadutos
# 2       Reparos em asfalto, pontes e viadutos
# 3       Reparos em asfalto, pontes e viadutos
# 4                           Reclamação ônibus
# 5       Reparos em asfalto, pontes e viadutos
# ...                                       ...
# 664938                        Coleta seletiva
# 664942  Reparos em asfalto, pontes e viadutos
# 664969                      Lixeiras Públicas
# 664970             Remoção de grandes objetos
# 664972     Capinação e roçada de áreas verdes
#
#                                                   Serviço  \
# 1                                             Tapa-buraco
# 2                                             Tapa-buraco
# 3                                             Tapa-buraco
# 4       Ônibus - Reclamação de intervalo excessivo da ...
# 5                                             Tapa-buraco
# ...                                                   ...
# 664938       Instalação de contêiner para coleta seletiva
# 664942                                        Tapa-buraco
# 664969                    Instalação e remoção de lixeira
# 664970        Remoção de grandes objetos em vias públicas
# 664972                      Capinação em guias e sarjetas
#
#                                   Logradouro  Número          CEP  \
# 1       Rua Doutor Paulo Furtado de Oliveira   401.0  2.67403e+06
# 2       Rua Doutor Paulo Furtado de Oliveira   341.0  2.67403e+06
# 3       Rua Doutor Paulo Furtado de Oliveira   250.0  2.67403e+06
# 4                                Rua Kotinda  1679.0  2.36501e+06
# 5       Rua Doutor Paulo Furtado de Oliveira   150.0  2.67403e+06
# ...                                      ...     ...          ...
# 664938                           Rua Itapiru   405.0  4.14301e+06
# 664942                    Rua dos Jequitibás   179.0  5.26303e+06
# 664969          Rua Adília Mercado Madureira    39.0  4.40107e+06
# 664970             Rua Voluntários da Pátria  2607.0   2.4011e+06
# 664972                     Rua Garção Tinoco    62.0  2.40202e+06
#
#                   Subprefeitura       Distrito  Setor  Quadra   Latitude  \
# 1       CASA VERDE-CACHOEIRINHA   CACHOEIRINHA  108.0    89.0 -23.459489
# 2       CASA VERDE-CACHOEIRINHA   CACHOEIRINHA  108.0    89.0 -23.459793
# 3       CASA VERDE-CACHOEIRINHA   CACHOEIRINHA  108.0    81.0 -23.460395
# 4               JACANA-TREMEMBE       TREMEMBE    NaN     NaN -23.425205
# 5       CASA VERDE-CACHOEIRINHA   CACHOEIRINHA  108.0    81.0 -23.460918
# ...                         ...            ...    ...     ...        ...
# 664938             VILA MARIANA          SAUDE   47.0    35.0 -23.615570
# 664942                JABAQUARA      JABAQUARA   91.0    17.0 -23.646634
# 664969            CIDADE ADEMAR  CIDADE ADEMAR  120.0   151.0 -23.666484
# 664970         SANTANA-TUCURUVI        SANTANA    NaN     NaN -23.497272
# 664972         SANTANA-TUCURUVI        SANTANA   69.0   163.0 -23.496424
#
#         Longitude     Data do parecer Status da solicitação    Órgão  \
# 1      -46.667533 2020-01-04 20:35:15            FINALIZADA    SMSUB
# 2      -46.668002 2020-01-04 20:36:10            FINALIZADA    SMSUB
# 3      -46.668632 2020-01-04 20:38:05            FINALIZADA    SMSUB
# 4      -46.582186 2020-02-08 06:11:29            FINALIZADA  SPTRANS
# 5      -46.669338 2020-01-04 20:36:12            FINALIZADA    SMSUB
# ...           ...                 ...                   ...      ...
# 664938 -46.635371 2020-07-02 17:30:33            FINALIZADA   AMLURB
# 664942 -46.642266 2020-07-07 23:13:27            FINALIZADA    SMSUB
# 664969 -46.665565 2020-07-01 17:51:01            FINALIZADA   AMLURB
# 664970 -46.625937 2020-07-01 00:25:32            FINALIZADA   AMLURB
# 664972 -46.624545 2020-07-01 00:25:46            FINALIZADA   AMLURB
#
#                               geometry
# 1       POINT (329675.999 7404626.542)
# 2       POINT (329628.476 7404592.355)
# 3       POINT (329564.918 7404524.956)
# 4       POINT (338353.381 7408521.455)
# 5       POINT (329493.475 7404466.214)
# ...                                ...
# 664938  POINT (333158.805 7387380.134)
# 664942  POINT (332494.788 7383932.063)
# 664969  POINT (330143.547 7381706.295)
# 664970  POINT (333972.850 7400491.220)
# 664972  POINT (334113.883 7400586.689)
#
# [144840 rows x 19 columns]

# %% [markdown]
# ## Tratando pontos fora dos limites do município de São Paulo
#
# Existem casos em que os pontos estão localizados fora dos limites do município de São Paulo e para finalidade de estudo vamos quantifica-los e discriminá-los para estudos posteriores.

# %%
msp = gpd.read_file('arquivos/SP.shp')
gdf_sp = gpd.sjoin(gdf, msp, how='left', op='within')

# %%
gdf[gdf_sp.municipio.isna()]
# Out:
#           index        Data de abertura  \
# 0             0 2020-01-01 00:00:15.000
# 7             7 2020-01-01 00:13:29.000
# 8             8 2020-01-01 00:14:56.000
# 9             9 2020-01-01 00:17:59.000
# 10           10 2020-01-01 00:19:21.000
# ...         ...                     ...
# 1019460  354480 2020-10-01 02:56:22.565
# 1019461  354481 2020-10-01 02:57:28.485
# 1019462  354482 2020-10-01 02:57:29.197
# 1019463  354483 2020-10-01 02:58:00.813
# 1019464  354484 2020-10-01 02:58:08.959
#
#                                             Canal  \
# 0                                   PORTAL ONLINE
# 7                              CENTRAL TELEFÔNICA
# 8                                   PORTAL ONLINE
# 9                              CENTRAL TELEFÔNICA
# 10                             CENTRAL TELEFÔNICA
# ...                                           ...
# 1019460                        CENTRAL TELEFÔNICA
# 1019461  PRAÇAS DE ATENDIMENTO DAS SUBPREFEITURAS
# 1019462                        CENTRAL TELEFÔNICA
# 1019463                        CENTRAL TELEFÔNICA
# 1019464                        CENTRAL TELEFÔNICA
#
#                                    Tema  \
# 0                          Rua e bairro
# 7        Cidadania e assistência social
# 8                          Rua e bairro
# 9                              Urgência
# 10       Cidadania e assistência social
# ...                                 ...
# 1019460                    Rua e bairro
# 1019461           Trânsito e Transporte
# 1019462  Cidadania e assistência social
# 1019463                        Urgência
# 1019464                        Urgência
#
#                                         Assunto  \
# 0                        Poluição Sonora - PSIU
# 7        População ou pessoa em situação de rua
# 8                        Poluição Sonora - PSIU
# 9                    Guarda Civil Metropolitana
# 10       População ou pessoa em situação de rua
# ...                                         ...
# 1019460                  Poluição Sonora - PSIU
# 1019461              Estacionamento e Zona Azul
# 1019462  População ou pessoa em situação de rua
# 1019463              Guarda Civil Metropolitana
# 1019464              Guarda Civil Metropolitana
#
#                                                    Serviço Logradouro  Número  \
# 0                     Reclamação de poluição sonora - PSIU        NaN     NaN
# 7        Serviço Especializado de Abordagem Social às P...        NaN     NaN
# 8                     Reclamação de poluição sonora - PSIU        NaN     NaN
# 9                                   Perturbação do sossego        NaN     NaN
# 10       Serviço Especializado de Abordagem Social às P...        NaN     NaN
# ...                                                    ...        ...     ...
# 1019460               Reclamação de poluição sonora - PSIU        NaN     NaN
# 1019461  Cartão de estacionamento DeFis (pessoa com def...        NaN     NaN
# 1019462  Serviço Especializado de Abordagem Social às P...        NaN     NaN
# 1019463                             Perturbação do sossego        NaN     NaN
# 1019464                             Perturbação do sossego        NaN     NaN
#
#          CEP     Subprefeitura     Distrito  Setor  Quadra  Latitude  \
# 0        NaN  SANTANA-TUCURUVI      SANTANA    NaN     NaN       NaN
# 7        NaN              LAPA         LAPA    NaN     NaN       NaN
# 8        NaN  SANTANA-TUCURUVI      SANTANA    NaN     NaN       NaN
# 9        NaN           BUTANTA  RIO PEQUENO    NaN     NaN       NaN
# 10       NaN  PIRITUBA-JARAGUA     PIRITUBA    NaN     NaN       NaN
# ...      ...               ...          ...    ...     ...       ...
# 1019460  NaN             MOOCA    AGUA RASA    NaN     NaN       NaN
# 1019461  NaN               NaN          NaN    NaN     NaN       NaN
# 1019462  NaN       SANTO AMARO  SANTO AMARO    NaN     NaN       NaN
# 1019463  NaN                SE   BELA VISTA    NaN     NaN       NaN
# 1019464  NaN   JACANA-TREMEMBE     TREMEMBE    NaN     NaN       NaN
#
#          Longitude         Data do parecer   Status da solicitação    Órgão  \
# 0              NaN                     NaT  AGUARDANDO ATENDIMENTO    SMSUB
# 7              NaN 2020-01-01 01:05:09.000              FINALIZADA    SMADS
# 8              NaN                     NaT  AGUARDANDO ATENDIMENTO    SMSUB
# 9              NaN 2020-01-01 01:36:53.000              FINALIZADA      GCM
# 10             NaN 2020-01-01 04:25:41.000              INDEFERIDO    SMADS
# ...            ...                     ...                     ...      ...
# 1019460        NaN                     NaT  AGUARDANDO ATENDIMENTO    SMSUB
# 1019461        NaN 2020-10-01 11:55:51.264              INDEFERIDO  SMT-DSV
# 1019462        NaN 2020-10-01 04:32:55.574              FINALIZADA    SMADS
# 1019463        NaN 2020-10-01 03:07:55.000              FINALIZADA      GCM
# 1019464        NaN 2020-10-01 03:16:00.000              FINALIZADA      GCM
#
#                 geometry
# 0        POINT (inf inf)
# 7        POINT (inf inf)
# 8        POINT (inf inf)
# 9        POINT (inf inf)
# 10       POINT (inf inf)
# ...                  ...
# 1019460  POINT (inf inf)
# 1019461  POINT (inf inf)
# 1019462  POINT (inf inf)
# 1019463  POINT (inf inf)
# 1019464  POINT (inf inf)
#
# [857218 rows x 19 columns]

# %% [markdown]
# ## Transformando Setor e Quadra em pontos
#
# Alguns registros de atendimento estão com informações de quadras ou setores fiscais e portanto deveriam ser representado pela feição do polígono
#
# Porém, para evitarmos múltiplas feições ou uma subtotalização transformar aqueles registros em um ponto no centroide da feição, uma vez que conhecemos as feições de Setor e Quadra. Como são casos menos frequentes podemos proporcionar uma melhor análise dessa maneira.
#
# Alias, poderíamos criar um ponto aleatório na feição para evitar a sobreposição, o que também pode ser uma estratégia.

# %%
log.write('## Transformando Registros que contém Setor e Quadra em pontos de Centroide das respectivas feições\n')
# Out:
# 100

# %%
zipfile = "zip:///home/fernando/dev/geo-sp156/arquivos/SIRGAS_SHP_setorfiscal.zip!SIRGAS_SHP_setorfiscal/SIRGAS_SHP_setorfiscal.shp"
df_setores = gpd.read_file(zipfile)

zipfile = "zip:///home/fernando/dev/geo-sp156/arquivos/SIRGAS_SHP_quadraMDSF.zip!SIRGAS_SHP_quadraMDSF/SIRGAS_SHP_quadraMDSF.shp"
df_quadras = gpd.read_file(zipfile)

# %%
df_quadras = df_quadras[df_quadras.qd_tipo == 'F']

# %%
df_setor = gdf[gdf.Latitude.isna() & ~gdf.Setor.isna() & gdf.Quadra.isna()]
df_quadra = gdf[gdf.Latitude.isna() & ~gdf.Setor.isna() & ~gdf.Quadra.isna()]

# %%
df_setor['st_codigo'] = df_setor.Setor.astype(int).apply(lambda x: '{:03d}'.format(x))
df_quadra['qd_setor'] = df_quadra.Setor.astype(int).apply(lambda x: '{:03d}'.format(x))
df_quadra['qd_fiscal'] = df_quadra.Quadra.astype(int).apply(lambda x: '{:03d}'.format(x))
# Out:
# /home/fernando/miniconda3/envs/geopandas/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
df_setor.st_codigo = df_setor.st_codigo.astype('str')
df_quadra.qd_setor = df_quadra.qd_setor.astype('str')
df_quadra.qd_fiscal = df_quadra.qd_fiscal.astype('str')

# %%
# REmovendo setores duplicados
df_setores = df_setores.drop(df_setores[df_setores.duplicated(['st_codigo'], keep=False)].index)

# %%
df_setores.geometry = df_setores.geometry.centroid

# %%
df_setor['id'] = df_setor.index

# %%
setor = df_setor.merge(df_setores[['geometry', 'st_codigo']], on=['st_codigo'], suffixes=('', '_y'), how='left')

# %%
setor = setor.set_index('id')

# %%
# Atualizando os centroind no DataFrame
gdf.loc[(gdf.Latitude.isna() & ~gdf.Setor.isna() & gdf.Quadra.isna()), 'geometry'] = setor.geometry_y

# %%
# REmovendo as quadras duplicadas
quadras = df_quadras.drop(df_quadras[df_quadras.duplicated(['qd_setor', 'qd_fiscal', 'qd_subqua'], keep=False)].index)

# %%
quadras = quadras.drop(quadras[quadras.qd_subqua != '001'].index)

# %%
quadras.geometry = quadras.geometry.centroid

# %%
df_quadra['id'] = df_quadra.index

# %%
quadra = df_quadra.merge(quadras[['geometry', 'qd_setor', 'qd_fiscal']], on=['qd_setor', 'qd_fiscal'], suffixes=('', '_y'), how='left')

# %%
quadra = quadra.set_index('id')

# %%
# Atualizando os centroind da quadra no DataFrame
gdf.loc[gdf.Latitude.isna() & ~gdf.Setor.isna() & ~gdf.Quadra.isna(), 'geometry'] = quadra.geometry_y

# %%
# gdf[gdf.geometry.is_valid].to_file('resultados/atendimentos-1-semestre-2020.gpkg', driver='GPKG')

# %%
# gdf[gdf.Serviço.str.contains('morcego')].is_valid.value_counts()

# %%
gdf.Serviço.unique()
# Out:
# array(['Reclamação de poluição sonora - PSIU', 'Tapa-buraco',
#        'Ônibus - Reclamação de intervalo excessivo da linha',
#        'Serviço Especializado de Abordagem Social às Pessoas em Situação de Rua - SEAS',
#        'Perturbação do sossego',
#        'Remoção de veículo/carcaça abandonado na via pública',
#        'Remoção de grandes objetos em vias públicas',
#        'Cartão de estacionamento idoso', 'Alarme disparado',
#        'Enquete SP156', 'Invasão', 'Apoio a agente público',
#        'Ocorrências com Drogas',
#        'Drenagem de água da chuva - Bueiros e bocas de lobo',
#        'Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)',
#        'Atitude Suspeita',
#        'Praças - Solicitar manutenção de equipamentos (mesas, bancos e brinquedos)',
#        'Guias, sarjetas e sarjetões - solicitar manutenção',
#        'Solicitar fiscalização de ambulantes',
#        'Fiscalização de veículo estacionado em local proibido',
#        'Reclamação', 'Denúncia',
#        'Morcego - Reclamar sobre local com morcego',
#        'Denunciar condições inadequadas de criação',
#        'Ônibus - Denúncia de alteração de itinerário ou ponto inicial/final',
#        'Vistoria de colmeia/vespeiro instalado',
#        'Aviso de semáforo com problemas',
#        'Fiscalização de obra e reforma em imóvel particular',
#        'Circulação e acesso de veículos e pessoas - Solicitar avaliação',
#        'Ônibus - Denúncia de conduta do motorista, cobrador ou fiscal',
#        'Ameaça', 'Ônibus - Denúncia de problemas no embarque/desembarque',
#        'Cães e gatos invasores de instituições públicas - Solicitar avaliação',
#        'Comércio irregular', 'Remoção de animal morto em via pública',
#        'Ônibus - Reclamação de descumprimento de partida no ponto inicial/final',
#        'Reclamações sobre coleta de lixo domiciliar',
#        'Solicitar avaliação de local com pernilongo/mosquito',
#        'Instalação e remoção de lixeira',
#        'Reclamação de falta de varrição',
#        'Execução de serviços em árvore localizada em área pública',
#        'Denunciar local com roedores/ratos',
#        'Roçada em praças e canteiro central', 'Risco de desabamento',
#        'Calçada pública - solicitar manutenção', 'Solicitação',
#        'Denunciar local com acúmulo de água limpa e parada',
#        'Ocorrências com animais silvestres',
#        'Comunicação de problema em posto de recarga', 'Queda de árvore',
#        'Denúncia de caçamba de entulho de obra/construção',
#        '[Solicitado pela Defesa Civil \x96 uso interno] Remoção de galhos e troncos',
#        'Agressão',
#        'Comunicação de erro em cobrança de integração (ônibus e metrô ou trem)',
#        'Manutenção e limpeza de parques públicos municipais',
#        'Capinação em guias e sarjetas',
#        'Remoção de entulho em via pública',
#        'Sugerir instalação de equipamentos de ginástica na praça',
#        'Denunciar descarte irregular de entulho e outros resíduos em área pública',
#        'Comércio, serviço e indústria - solicitar fiscalização de funcionamento',
#        'Ônibus - Denúncia de direção inadequada ou perigosa de veículo',
#        'Descarte de entulho em flagrante',
#        'Limpeza de bueiros, boca de lobo e poços de visita',
#        'Avisar sobre animal agressor em vias públicas',
#        'CPOM - Fale com a Fazenda',
#        'Denúncia de ocupação irregular de área verde localizada em área privada dentro do município',
#        'Lavagem especial de locais públicos',
#        'Bilhete Único Comum - Solicitação de relatório de utilização ou recarga',
#        'Denunciar irregularidade nos serviços para população em situação de rua',
#        'SPTrans - Sugestão',
#        'Cata Bagulho - Reclamação de não retirada de material',
#        'Invasão de áreas municipais',
#        'Bilhete Único Comum - Correção de dado cadastral',
#        'Ônibus - Reclamação de demora na partida',
#        'Acessibilidade - solicitar avaliação de obstáculo na calçada',
#        'Bilhete Único Idoso ou Pessoa com Deficiência - Correção de dado cadastral',
#        'Agendamento Eletrônico \x96 Fale com a Fazenda',
#        'Implantação de coleta porta-porta',
#        'Denunciar local com escorpião',
#        'Calçada particular - denunciar calçada danificada ou inexistente',
#        'Outras ocorrências em escolas',
#        'Vale Transporte - Solicitação de relatório de utilização ou recarga',
#        'Lixo domiciliar \x96 Denunciar colocação de lixo fora do horário de coleta',
#        'Risco iminente de queda de árvore',
#        'Denunciar falta de limpeza de terrenos e imóveis particulares',
#        'Resgate de animais silvestres acidentados ou feridos',
#        'Cartão de estacionamento DeFis (pessoa com deficiência)',
#        'Bilhete Único Idoso ou Pessoa com Deficiência - Apresentação de justificativa após bloqueio por reconhecimento facial',
#        'Denunciar terreno com muro danificado/inexistente',
#        'Implantação de abrigo ou ponto de ônibus',
#        'Praças - sugerir reforma e revitalização',
#        'Denunciar poda ou remoção não autorizada de árvore',
#        'Bilhete Único Estudante - Apresentação de justificativa após bloqueio por reconhecimento facial',
#        'Queda de galho', 'Alagamento', 'Pintura de guias e postes',
#        'Bilhete Único Estudante - Alteração da Cota Trilho para estudante que tenha a gratuidade no benefício e utiliza o Vale Transporte no mesmo Bilhete Único',
#        'Poda ou remoção de árvores ou vegetação em parques', 'Inundação',
#        'Vistoria e reparo de pontes e viadutos',
#        'Bilhete Único Estudante - Inclusão de mais um tipo de modalidade (ônibus ou metrô/CPTM) na cota mensal',
#        'Corrigir cadastro no Portal SP156',
#        'Rodízio de veículos - Isenção para pessoa com deficiência (PCD)',
#        'Recuperar galerias de águas de chuvas (pluviais)',
#        'Manutenção de placas de trânsito',
#        'Leve Leite - Reclamação de não entrega do leite',
#        'Manutenção, conserto e limpeza de ponto de ônibus',
#        'Sinalização horizontal apagada (pintura de solo) \x96 Solicitar repintura',
#        'Elogio', 'Infiltração', 'Bilhete Único - Falha na recarga',
#        'Limpeza do ônibus',
#        'Bilhete Único Idoso ou Pessoa com Deficiência - Envio de documento complementar',
#        'Limpar lixeiras públicas', 'Limpeza de córrego',
#        'Rachadura de Edificação',
#        'CCM (Cadastro de Contribuintes Mobiliários) \x96 Fale com a Fazenda',
#        'Crimes contra o meio ambiente',
#        'Licença especial de transporte de produtos perigosos - 1ª Licença',
#        'Limpeza da via pública após enchentes ou eventos',
#        'Bilhete Único Estudante - Bloqueio por  GIS',
#        'Denunciar despejo irregular de água usada ou esgoto',
#        'ISS - Fale com a Fazenda',
#        'Emissão de Certidões - Fale com a Fazenda',
#        'Central 156 - Reclamação', 'Denúncia de local com pombos',
#        'Remoção de contêiner para coleta de lixo domiciliar',
#        'Manutenção de vielas e escadarias',
#        'Sugerir criação e ampliação de estacionamento de veículos em vias públicas',
#        'Circulação de caminhões - Solicitar avaliação',
#        'Devolução da cota-parte do IPVA de carros híbridos',
#        'Reclamação de não remoção dos sacos de varrição',
#        'Denúncia de loteamento irregular ou clandestino',
#        'Ônibus - Reclamação de veículo com superlotação',
#        'Bilhete Único Estudante ou Professor - Inclusão de cotas para quem estuda ou trabalha em duas escolas',
#        'Plantio de árvores em passeio público ou calçada',
#        'Documentos (uso exclusivo de servidores da OGM)',
#        'Reclamações sobre coleta seletiva',
#        'Programa Bolsa Família - Reclamação de problemas com o benefício',
#        'Rodízio de veículos - Substituir veículo de isenção PCD',
#        'ITBI - Fale com a Fazenda', 'Nota do Milhão - Fale com a Fazenda',
#        'Instalação de contêiner para coleta seletiva',
#        'Instalação de contêiner para coleta de lixo domiciliar',
#        'Remanejamento de ponto de ônibus',
#        'Denunciar reserva irregular de vaga',
#        'Certidão negativa referente a denúncias ambientais',
#        'Central 156 - Elogio',
#        'Denúncia de má conduta dos funcionários (motoristas /coletores)',
#        'Conserto de lixeira', 'Ônibus - Manutenção do veículo em geral',
#        'Travessia de pedestres - Solicitar avaliação',
#        'Vale Transporte - Reclamação de crédito adquirido e não disponibilizado',
#        'Denúncia de má conduta dos funcionários de limpeza',
#        'Desabamento',
#        'Bilhete Único Idoso ou Pessoa com Deficiência - Alteração de nome civil para nome social',
#        'IPTU - Fale com a Fazenda',
#        'Solicitar fiscalização de estabelecimento com venda de bebida alcoólica entre 1h e 5h da manhã',
#        'Parcelamento de Tributos - Fale com a Fazenda',
#        'Empreenda Fácil - Suporte Técnico',
#        'Bilhete Único Estudante - Liberação de gratuidade mensal',
#        'Manutenção de placa com nome de rua',
#        'Certificado de Reservista \x96 2ª via',
#        'Processo administrativo - Fale com a Fazenda',
#        'Vale Transporte - Correção de dado cadastral',
#        'Risco de deslizamento',
#        'Taxas Mobiliárias \x96 Fale com a Fazenda', 'Erosão',
#        'Intensificar fiscalização de veículos em movimento',
#        'Tapa-buraco em faixa exclusiva ou corredor de ônibus',
#        'Ônibus - Elogio ao motorista, cobrador ou fiscal',
#        'Animal de grande porte solto - Solicitar remoção',
#        'Remoção de propaganda irregular',
#        'Taxi / Aplicativos - Denúncia de conduta ou postura do condutor',
#        'DUC - Fale com a Fazenda',
#        'Ônibus - Alteração de itinerário ou ponto inicial/final',
#        'Deslizamento',
#        'Vale Transporte - Solicitação de reembolso ou complemento de pagamento indevido',
#        'Denunciar janela ou abertura a menos de 1,50m do vizinho',
#        'Certificado de Dispensa de Incorporação (CDI) - 2ª via',
#        'Bilhete Único Estudante ou Professor - Correção de dado cadastral',
#        'Nivelamento de vias de terra', 'Comunicar leilão de imóvel',
#        'Intensificar fiscalização de veículos estacionados/parados irregularmente',
#        'Guias para travessia de pedestres - Solicitar rebaixamento',
#        'Semáforo de veículos e pedestres - Sugerir ajuste de tempo',
#        'Bilhete Único Estudante ou Professor - Suporte às escolas',
#        'Sugestão', 'Instalação de placa com nome de rua',
#        'Denúncia de edificação não adaptada às normas de segurança',
#        'Denunciar material de construção depositado em vias públicas',
#        'Reclamação de falta de limpeza de ruas após a feira',
#        'Criação/reativação de linha de ônibus',
#        'Solicitar fiscalização de feira livre',
#        'Denúncia de cheiro forte causando incômodo', 'Tumulto',
#        'Denúncia de fumaça/ fuligem /material particulado',
#        'Senha Web - Fale com a Fazenda',
#        'Análise de Plano de Atendimento a Emergência no Transporte de Produtos Perigosos',
#        'Reclamações sobre coleta de resíduos de serviços de saúde',
#        'Bilhete Único Estudante ou Professor - Suporte ao usuário sobre boleto',
#        'Maria da Penha',
#        '[Solicitado pela Defesa Civil - uso interno] Apoio a órgãos públicos',
#        'Denúncia de despejo irregular de esgoto ou outros poluentes de águas dentro dos limites do município',
#        'Programa Bolsa Família -  Denúncia de cadastramento/recebimento de benefício indevido',
#        'Material Escolar - Reclamar de atraso ou erro na entrega',
#        'Denúncia de irregularidade em locais com lotação superior a 250 pessoas',
#        'Alistamento no Serviço Militar - Fora do Prazo',
#        'Bilhete Único Estudante ou Professor - Solicitação de reembolso ou complemento de pagamento indevido',
#        'Manifestação pública',
#        'Rodízio de veículos - Isenção para PCD (pessoa jurídica)',
#        'Árvore em área interna - Solicitar avaliação da Prefeitura',
#        'Árvore em área interna - Comunicar poda à Prefeitura',
#        'Programa VAI - Inscrever projetos',
#        'Árvore em área interna - Comunicar remoção ou poda emergencial à Prefeitura',
#        'Denunciar estabelecimento que se manteve aberto durante a crise do Coronavirus',
#        'Solicitar certidão de auto de multa de imóvel',
#        'Dívida Ativa - Contestar ou solicitar baixa de débito',
#        'Solicitar remoção de veículo/carcaça abandonado na via pública',
#        'Solicitar fiscalização de obra e reforma em imóvel particular',
#        'Denunciar invasão de áreas municipais',
#        'Solicitar limpeza de bueiros, boca de lobo e poços de visita',
#        'Denunciar loteamento irregular ou clandestino',
#        'Árvore - solicitar manejo em área pública',
#        'Entregar Receitas de Medicamentos de Controle Especial Emergenciais ou oriundas de outros estados',
#        'Praça e canteiro central - solicitar roçada',
#        'Córrego - solicitar limpeza',
#        'Entregar Balanços de Substâncias e Medicamentos Psicoativos e Outras Substâncias de Controle Especial \x96 Distribuidoras e Indústrias',
#        'Árvore - denunciar poda ou remoção não autorizada',
#        'Vielas e escadarias - solicitar manutenção',
#        'Entregar balanços de substâncias e medicamentos psicoativos e outras substâncias de controle especial \x96 Farmácias de manipulação e drogarias',
#        'Denunciar estabelecimento que não fornece álcool em gel ou permite entrada sem máscara durante a crise do Coronavírus',
#        'Dívida Ativa - Tirar dúvidas sobre serviços relacionados',
#        'Programa Jovem Monitor Cultural - Fazer inscrição',
#        'Rodizio de Veiculos (coronavírus) - Cadastrar veículos para isenção durante a pandemia',
#        'Castrar cães e gatos gratuitamente',
#        'Nota do Milhão - Primeiro acesso - Solicitar orientações para configurar como MEI',
#        'Solicitar cadastro de prescritor de medicamentos de controle especial',
#        'Solicitar Numeração e/ ou Talonário de receitas de medicamentos de controle especial',
#        'Programa Bolsa Família - Consultar situação do benefício',
#        'Senha Web - Desbloqueio online para MEI, Empresário Individual e Pessoa Física',
#        'Reclamação Anônima (Uso exclusivo da Ouvidoria)',
#        'Programa de Fomento à Cultura da Periferia - Inscrever projetos',
#        'CadÚnico - Consultar número NIS',
#        'Entregar balanços de substâncias e medicamentos psicoativos e outras substâncias de controle especial – Farmácias de manipulação e drogarias',
#        'Sinalização horizontal apagada (pintura de solo) – Solicitar repintura',
#        'Lixo domiciliar – Denunciar colocação de lixo fora do horário de coleta',
#        'CCM – Fale com a Fazenda',
#        'Entregar Balanços de Substâncias e Medicamentos Psicoativos e Outras Substâncias de Controle Especial – Distribuidoras e Indústrias',
#        '(antigo) Reformar galerias de águas de chuvas (pluviais)',
#        'Taxas Mobiliárias – Fale com a Fazenda',
#        'Certificado de Reservista – 2ª via',
#        'Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo',
#        'Cartão alimentação - reclamar de problemas relacionados ao cartão alimentação'],
#       dtype=object)

# %% [markdown]
# ## Totalizando serviços por distrito
#
# Quando o atendimento gera apenas uma informação do distrito uma estratégia é totalizar os atendimentos por cada distrito.

# %%
log.write('## Totalizando serviços por Distrito\n')
# Out:
# 37

# %%
df_distritos = gpd.read_file('arquivos/SIRGAS_SHP_distrito_polygon.shp')

# %%
df_distritos.crs = 'epsg:31983'

# %%
log.write(f'- Removendo {len(df[df.Distrito.isna()])} registros que não tem informação de distrito nem outra informação espacial\n')
# Out:
# 94

# %%
df_distrito = df[~df.Distrito.isna()]

# %%
log.write(f'- Totalizando {len(df_distrito.Tema.unique())} temas distintos\n')
# Out:
# 33

# %%
log.write(f'- Totalizando {len(df_distrito.Serviço.unique())} serviços distintos\n')
# Out:
# 37

# %%
# pd.get_dummies(df[['Distrito', 'Serviço']][~df['Distrito'].isna()], columns=['Serviço']).groupby(['Distrito']).sum()

# %%
log.write(f'- Totalizando {len(gdf[~gdf.geometry.is_valid & ~gdf.Quadra.isna() & ~gdf.Setor.isna()])} registros sem Setor e Quadra válidos\n')
# Out:
# 56

# %%
log.write("## Gerando totalizações de camadas\n")
# Out:
# 35

# %%
# for t in gdf.Tema.unique():
#     print(f"{t}: ({len(gdf[(gdf.Tema == t)])})")
#     log.write(f"{t}: ({len(gdf[(gdf.Tema == t)])})\n")
#     for s in gdf[(gdf.Tema == t)].Serviço.unique():
#         g = len(gdf[(gdf.Serviço == s)])
#         g_valids = len(gdf[gdf.geometry.is_valid & (gdf.Serviço == s)])
#         print(f"  {s}: ({g}: {g_valids} pontos, {g-g_valids} agregado por distrito)")
#         log.write(f"  {s}: ({g}: {g_valids} pontos, {g-g_valids} agregado por distrito)\n")

# %% [markdown]
# ## Centroide do Distrito para casos em que alguns registros não são localizados
#
# Alguns serviços possuem uma  baixa porcentagem de casos onde não há possibilidade de localização. Para isso vamos determinar que até 20% de registros não localizados, serão referenciados no centroide do distrito afim de continua-la tratando como camada de pontos

# %%
df_distritos
# Out:
#    ds_codigo          ds_nome  \
# 0         51         MANDAQUI
# 1         52         MARSILAC
# 2         32            MOEMA
# 3         57  PARQUE DO CARMO
# 4         60         PERDIZES
# ..       ...              ...
# 91        41          JAGUARE
# 92        42          JARAGUA
# 93        44    JARDIM HELENA
# 94        45  JARDIM PAULISTA
# 95        46  JARDIM SAO LUIS
#
#                                              geometry
# 0   POLYGON ((330950.373 7407837.176, 330952.177 7...
# 1   POLYGON ((336124.090 7355302.282, 336121.755 7...
# 2   POLYGON ((331242.174 7392162.324, 331244.581 7...
# 3   POLYGON ((352597.619 7390119.444, 352588.233 7...
# 4   POLYGON ((330181.745 7396056.840, 330175.535 7...
# ..                                                ...
# 91  POLYGON ((322952.516 7394978.618, 323250.620 7...
# 92  POLYGON ((319172.403 7405179.204, 319174.204 7...
# 93  POLYGON ((352915.621 7402621.049, 352944.248 7...
# 94  POLYGON ((329605.461 7390837.489, 329600.764 7...
# 95  POLYGON ((321628.005 7377780.623, 321626.439 7...
#
# [96 rows x 3 columns]

# %%
gdf_servicos_pontos = gdf[gdf.is_valid].groupby(by=['Serviço']).agg({
    'geometry':'count'}).rename(columns={'geometry':'total_atendimentos_pontos'})

# %%
diferenca_total_distritos = pd.concat([gdf[gdf.Serviço.isin(gdf_servicos_pontos.index)].groupby(by=['Serviço']).agg({
    'geometry':'count'}).rename(columns={'geometry':'total_atendimentos'}),gdf_servicos_pontos], axis=1)

# %%
diferenca_total_distritos[(diferenca_total_distritos.total_atendimentos_pontos/diferenca_total_distritos.total_atendimentos)>0.8]
# Out:
#                                                     total_atendimentos  \
# Serviço
# (antigo) Reformar galerias de águas de chuvas (...                 334
# Avaliação de animal em sofrimento sem proprietá...                1049
# Avisar sobre animal agressor em vias públicas                      865
# Capinação em guias e sarjetas                                    10299
# Cata Bagulho - Reclamação de não retirada de ma...                2667
# Conserto de lixeira                                                219
# Denúncia de má conduta dos funcionários (motori...                 382
# Denúncia de má conduta dos funcionários de limpeza                 276
# Fiscalização de veículo estacionado em local pr...                3284
# Implantação de coleta porta-porta                                  246
# Instalação de contêiner para coleta de lixo dom...                 623
# Instalação de contêiner para coleta seletiva                       417
# Instalação e remoção de lixeira                                   6070
# Lavagem especial de locais públicos                               1806
# Limpeza da via pública após enchentes ou eventos                   796
# Limpeza de bueiros, boca de lobo e poços de visita                5922
# Manutenção de placas de trânsito                                  1680
# Morcego - Reclamar sobre local com morcego                        1106
# Pintura de guias e postes                                          789
# Reclamação de falta de limpeza de ruas após a f...                 288
# Reclamação de falta de varrição                                  11381
# Reclamação de não remoção dos sacos de varrição                    846
# Reclamações sobre coleta de lixo domiciliar                       4243
# Reclamações sobre coleta de resíduos de serviço...                 572
# Reclamações sobre coleta seletiva                                  944
# Sinalização horizontal apagada (pintura de solo...                 994
# Sinalização horizontal apagada (pintura de solo...                 529
# Solicitar avaliação de local com pernilongo/mos...                2862
# Solicitar limpeza de bueiros, boca de lobo e po...                7488
# Tapa-buraco                                                      79309
# Tapa-buraco em faixa exclusiva ou corredor de ô...                1526
# Vistoria de colmeia/vespeiro instalado                            6422
# Ônibus - Denúncia de direção inadequada ou peri...                1819
# Ônibus - Reclamação de intervalo excessivo da l...                9569
#
#                                                     total_atendimentos_pontos
# Serviço
# (antigo) Reformar galerias de águas de chuvas (...                        286
# Avaliação de animal em sofrimento sem proprietá...                        868
# Avisar sobre animal agressor em vias públicas                             727
# Capinação em guias e sarjetas                                           10043
# Cata Bagulho - Reclamação de não retirada de ma...                       2575
# Conserto de lixeira                                                       205
# Denúncia de má conduta dos funcionários (motori...                        329
# Denúncia de má conduta dos funcionários de limpeza                        255
# Fiscalização de veículo estacionado em local pr...                       3188
# Implantação de coleta porta-porta                                         233
# Instalação de contêiner para coleta de lixo dom...                        580
# Instalação de contêiner para coleta seletiva                              399
# Instalação e remoção de lixeira                                          5824
# Lavagem especial de locais públicos                                      1737
# Limpeza da via pública após enchentes ou eventos                          786
# Limpeza de bueiros, boca de lobo e poços de visita                       5922
# Manutenção de placas de trânsito                                         1621
# Morcego - Reclamar sobre local com morcego                               1025
# Pintura de guias e postes                                                 744
# Reclamação de falta de limpeza de ruas após a f...                        282
# Reclamação de falta de varrição                                         10908
# Reclamação de não remoção dos sacos de varrição                           833
# Reclamações sobre coleta de lixo domiciliar                              3748
# Reclamações sobre coleta de resíduos de serviço...                        550
# Reclamações sobre coleta seletiva                                         869
# Sinalização horizontal apagada (pintura de solo...                        994
# Sinalização horizontal apagada (pintura de solo...                        448
# Solicitar avaliação de local com pernilongo/mos...                       2703
# Solicitar limpeza de bueiros, boca de lobo e po...                       6827
# Tapa-buraco                                                             75648
# Tapa-buraco em faixa exclusiva ou corredor de ô...                       1492
# Vistoria de colmeia/vespeiro instalado                                   5890
# Ônibus - Denúncia de direção inadequada ou peri...                       1734
# Ônibus - Reclamação de intervalo excessivo da l...                       9083

# %%
gdf_servicos_pontos = diferenca_total_distritos[(diferenca_total_distritos.total_atendimentos_pontos/diferenca_total_distritos.total_atendimentos)>0.8]

# %%
servicos_sem_ponto_com_distrito = gdf[gdf.Serviço.isin(gdf_servicos_pontos.index) & ~gdf.is_valid & ~gdf.Subprefeitura.isna()]['Distrito']

# %%
servicos_sem_ponto_com_distrito
# Out:
# 363        JARDIM ANGELA
# 393        JARDIM ANGELA
# 440             PEDREIRA
# 485        CIDADE ADEMAR
# 590               GRAJAU
#                ...
# 1019061        SAPOPEMBA
# 1019122      PARELHEIROS
# 1019281      BRASILANDIA
# 1019310            PENHA
# 1019331            PENHA
# Name: Distrito, Length: 8828, dtype: object

# %%
servicos_sem_ponto_com_distrito = pd.DataFrame(servicos_sem_ponto_com_distrito)
servicos_sem_ponto_com_distrito['index'] = servicos_sem_ponto_com_distrito.index

# %%
servicos_sem_ponto_com_distrito
# Out:
#               Distrito    index
# 363      JARDIM ANGELA      363
# 393      JARDIM ANGELA      393
# 440           PEDREIRA      440
# 485      CIDADE ADEMAR      485
# 590             GRAJAU      590
# ...                ...      ...
# 1019061      SAPOPEMBA  1019061
# 1019122    PARELHEIROS  1019122
# 1019281    BRASILANDIA  1019281
# 1019310          PENHA  1019310
# 1019331          PENHA  1019331
#
# [8828 rows x 2 columns]

# %%
df_distritos['centroide'] = df_distritos.geometry.centroid

# %%
centroide_distritos = servicos_sem_ponto_com_distrito.merge(df_distritos, left_on='Distrito', right_on='ds_nome').set_index('index').centroide

# %%
gdf.is_valid.value_counts()
# Out:
# False    794031
# True     207937
# dtype: int64

# %%
#### TODO não está atribuindo o centroide

# gdf
# gdf.iloc[gdf.index.isin(centroide_distritos.index)].geometry #= centroide_distritos
centroide_distritos.index.name = ''
centroide_distritos
# Out:
# 363        POINT (319690.025 7376055.851)
# 393        POINT (319690.025 7376055.851)
# 1192       POINT (319690.025 7376055.851)
# 9968       POINT (319690.025 7376055.851)
# 11151      POINT (319690.025 7376055.851)
#                         ...
# 944967     POINT (333445.768 7392767.705)
# 944974     POINT (333445.768 7392767.705)
# 982953     POINT (333445.768 7392767.705)
# 1002090    POINT (333445.768 7392767.705)
# 1017769    POINT (333445.768 7392767.705)
# Name: centroide, Length: 8828, dtype: geometry

# %%
gdf.iloc[gdf.index.isin(centroide_distritos.index), gdf.columns.get_loc('geometry')] = centroide_distritos

# %%
gdf.iloc[gdf.index.isin(centroide_distritos.index), gdf.columns.get_loc('geometry')]
# Out:
# 363        POINT (319690.025 7376055.851)
# 393        POINT (319690.025 7376055.851)
# 440        POINT (331801.371 7377266.082)
# 485        POINT (331045.774 7380907.159)
# 590        POINT (329981.185 7368063.452)
#                         ...
# 1019061    POINT (345985.963 7388629.437)
# 1019122    POINT (325151.304 7363541.607)
# 1019281    POINT (327531.212 7405808.370)
# 1019310    POINT (343888.326 7397736.879)
# 1019331    POINT (343888.326 7397736.879)
# Name: geometry, Length: 8828, dtype: geometry

# %% [markdown]
# ## Gerando o arquivo das camadas
#
# Agora vamos gerar um arquivo GeoPackage com um padrão de nomes assim:
#
# * Tema - Geometria - Serviço
#
# Isso tanto para os pontos quanto para as totalizações por distrito

# %%
log.write("## Gerando camadas de polígonos\n")
# Out:
# 32

# %%
poligonos = gdf[~gdf.Serviço.isin(gdf_servicos_pontos.index)]

# %%
# gdf_servicos_pontos[gdf_servicos_pontos.index.str.contains('morcego')]

# %%
poligonos[['AGUARDANDO ATENDIMENTO','CANCELADA','FINALIZADA','INDEFERIDO']] = pd.get_dummies(poligonos['Status da solicitação'])
# Out:
# /home/fernando/miniconda3/envs/geopandas/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
poligonos.dtypes
# Out:
# index                              int64
# Data de abertura          datetime64[ns]
# Canal                             object
# Tema                              object
# Assunto                           object
# Serviço                           object
# Logradouro                        object
# Número                           float64
# CEP                               object
# Subprefeitura                     object
# Distrito                          object
# Setor                            float64
# Quadra                           float64
# Latitude                         float64
# Longitude                        float64
# Data do parecer           datetime64[ns]
# Status da solicitação             object
# Órgão                             object
# geometry                        geometry
# AGUARDANDO ATENDIMENTO             uint8
# CANCELADA                          uint8
# FINALIZADA                         uint8
# INDEFERIDO                         uint8
# dtype: object

# %%
(poligonos[['Distrito', 'AGUARDANDO ATENDIMENTO', 'CANCELADA', 'FINALIZADA', 'INDEFERIDO', 'Data de abertura']]
 .groupby(['Distrito'])
 .agg({
     'AGUARDANDO ATENDIMENTO':'sum',
     'CANCELADA':'sum',
     'FINALIZADA':'sum',
     'INDEFERIDO':'sum',
     'Data de abertura':'count'
 })
 .rename(columns={'Data de abertura':'total_atendimentos'}))
# Out:
#                    AGUARDANDO ATENDIMENTO  CANCELADA  FINALIZADA  INDEFERIDO  \
# Distrito
# AGUA RASA                           706.0         37      2965.0       382.0
# ALTO DE PINHEIROS                   418.0          4      1856.0       268.0
# ANHANGUERA                          311.0          5      1275.0       114.0
# ARICANDUVA                          525.0         13      2322.0       314.0
# ARTUR ALVIM                         512.0         15      2453.0       212.0
# ...                                   ...        ...         ...         ...
# VILA MARIANA                       1007.0         33      4083.0       578.0
# VILA MATILDE                        965.0         15      3204.0       360.0
# VILA MEDEIROS                       840.0         21      4159.0       346.0
# VILA PRUDENTE                       851.0         36      3840.0       385.0
# VILA SONIA                          684.0         19      3237.0       268.0
#
#                    total_atendimentos
# Distrito
# AGUA RASA                        4090
# ALTO DE PINHEIROS                2546
# ANHANGUERA                       1705
# ARICANDUVA                       3174
# ARTUR ALVIM                      3192
# ...                               ...
# VILA MARIANA                     5701
# VILA MATILDE                     4544
# VILA MEDEIROS                    5366
# VILA PRUDENTE                    5112
# VILA SONIA                       4208
#
# [96 rows x 5 columns]

# %%
df_distritos = df_distritos.drop('centroide', axis=1)

# %%
for t in poligonos.Tema.unique():
    log.write(f"{t}: ({len(poligonos[(poligonos.Tema == t)])})\n")
    for s in poligonos[(poligonos.Tema == t)].Serviço.unique():
        log.write(f"  {s}: ({len(poligonos[(poligonos.Serviço == s)])})\n")
        c = (poligonos[poligonos.Serviço == s][['Distrito', 'AGUARDANDO ATENDIMENTO', 'CANCELADA', 'FINALIZADA', 'INDEFERIDO', 'Data de abertura']]
             .groupby(['Distrito'])
             .agg({
                 'AGUARDANDO ATENDIMENTO':'sum',
                 'CANCELADA':'sum',
                 'FINALIZADA':'sum',
                 'INDEFERIDO':'sum',
                 'Data de abertura':'count'
             })
             .rename(columns={'Data de abertura':'total_atendimentos'}))
        r = df_distritos.merge(c, left_on='ds_nome', right_on='Distrito')
        if len(r) > 1:
            r.to_file(f'resultados/Visualizador-156-2020.gpkg', layer=f'{t} - Polígono - {s}', driver='GPKG')

# %%
log.write("## Gerando camadas de pontos\n")
# Out:
# 29

# %%
gdf_sp = gpd.sjoin(gdf, gpd.GeoDataFrame([{'municipio':'São Paulo'}], geometry=msp.geometry.buffer(1000)), how='left', op='within')

# %%
# gpd.GeoDataFrame([{'municipio':'São Paulo'}], geometry=msp.geometry.buffer(1000)).plot()

# %%
# len(gdf_sp)

# %%
pontos = gdf[gdf.Serviço.isin(gdf_servicos_pontos.index) & ~gdf_sp.municipio.isna()]

# %%
gdf[gdf.Serviço.isin(gdf_servicos_pontos.index) & ~gdf_sp.municipio.isna()]
# gdf[gdf.Serviço.isin(gdf_servicos_pontos.index)]
# Out:
#          index    Data de abertura               Canal                   Tema  \
# 1            1 2020-01-01 00:01:18          APLICATIVO           Rua e bairro
# 2            2 2020-01-01 00:04:13          APLICATIVO           Rua e bairro
# 3            3 2020-01-01 00:06:57          APLICATIVO           Rua e bairro
# 4            4 2020-01-01 00:08:05  CENTRAL TELEFÔNICA  Trânsito e Transporte
# 5            5 2020-01-01 00:09:19          APLICATIVO           Rua e bairro
# ...        ...                 ...                 ...                    ...
# 664923  664923 2020-06-30 23:03:21       PORTAL ONLINE           Rua e bairro
# 664938  664938 2020-06-30 23:20:16       PORTAL ONLINE         Lixo e limpeza
# 664942  664942 2020-06-30 23:22:10       PORTAL ONLINE           Rua e bairro
# 664969  664969 2020-06-30 23:46:19          APLICATIVO         Lixo e limpeza
# 664972  664972 2020-06-30 23:56:28          APLICATIVO           Rua e bairro
#
#                                       Assunto  \
# 1       Reparos em asfalto, pontes e viadutos
# 2       Reparos em asfalto, pontes e viadutos
# 3       Reparos em asfalto, pontes e viadutos
# 4                           Reclamação ônibus
# 5       Reparos em asfalto, pontes e viadutos
# ...                                       ...
# 664923  Reparos em asfalto, pontes e viadutos
# 664938                        Coleta seletiva
# 664942  Reparos em asfalto, pontes e viadutos
# 664969                      Lixeiras Públicas
# 664972     Capinação e roçada de áreas verdes
#
#                                                   Serviço  \
# 1                                             Tapa-buraco
# 2                                             Tapa-buraco
# 3                                             Tapa-buraco
# 4       Ônibus - Reclamação de intervalo excessivo da ...
# 5                                             Tapa-buraco
# ...                                                   ...
# 664923                                        Tapa-buraco
# 664938       Instalação de contêiner para coleta seletiva
# 664942                                        Tapa-buraco
# 664969                    Instalação e remoção de lixeira
# 664972                      Capinação em guias e sarjetas
#
#                                   Logradouro  Número          CEP  \
# 1       Rua Doutor Paulo Furtado de Oliveira   401.0  2.67403e+06
# 2       Rua Doutor Paulo Furtado de Oliveira   341.0  2.67403e+06
# 3       Rua Doutor Paulo Furtado de Oliveira   250.0  2.67403e+06
# 4                                Rua Kotinda  1679.0  2.36501e+06
# 5       Rua Doutor Paulo Furtado de Oliveira   150.0  2.67403e+06
# ...                                      ...     ...          ...
# 664923                Rua João Alves Pimenta   530.0    2.967e+06
# 664938                           Rua Itapiru   405.0  4.14301e+06
# 664942                    Rua dos Jequitibás   179.0  5.26303e+06
# 664969          Rua Adília Mercado Madureira    39.0  4.40107e+06
# 664972                     Rua Garção Tinoco    62.0  2.40202e+06
#
#                   Subprefeitura        Distrito  Setor  Quadra   Latitude  \
# 1       CASA VERDE-CACHOEIRINHA    CACHOEIRINHA  108.0    89.0 -23.459489
# 2       CASA VERDE-CACHOEIRINHA    CACHOEIRINHA  108.0    89.0 -23.459793
# 3       CASA VERDE-CACHOEIRINHA    CACHOEIRINHA  108.0    81.0 -23.460395
# 4               JACANA-TREMEMBE        TREMEMBE    NaN     NaN -23.425205
# 5       CASA VERDE-CACHOEIRINHA    CACHOEIRINHA  108.0    81.0 -23.460918
# ...                         ...             ...    ...     ...        ...
# 664923    FREGUESIA-BRASILANDIA  FREGUESIA DO O  307.0    71.0 -23.481408
# 664938             VILA MARIANA           SAUDE   47.0    35.0 -23.615570
# 664942                JABAQUARA       JABAQUARA   91.0    17.0 -23.646634
# 664969            CIDADE ADEMAR   CIDADE ADEMAR  120.0   151.0 -23.666484
# 664972         SANTANA-TUCURUVI         SANTANA   69.0   163.0 -23.496424
#
#         Longitude     Data do parecer Status da solicitação    Órgão  \
# 1      -46.667533 2020-01-04 20:35:15            FINALIZADA    SMSUB
# 2      -46.668002 2020-01-04 20:36:10            FINALIZADA    SMSUB
# 3      -46.668632 2020-01-04 20:38:05            FINALIZADA    SMSUB
# 4      -46.582186 2020-02-08 06:11:29            FINALIZADA  SPTRANS
# 5      -46.669338 2020-01-04 20:36:12            FINALIZADA    SMSUB
# ...           ...                 ...                   ...      ...
# 664923 -46.708198 2020-07-13 12:40:04            INDEFERIDO    SMSUB
# 664938 -46.635371 2020-07-02 17:30:33            FINALIZADA   AMLURB
# 664942 -46.642266 2020-07-07 23:13:27            FINALIZADA    SMSUB
# 664969 -46.665565 2020-07-01 17:51:01            FINALIZADA   AMLURB
# 664972 -46.624545 2020-07-01 00:25:46            FINALIZADA   AMLURB
#
#                               geometry
# 1       POINT (329675.999 7404626.542)
# 2       POINT (329628.476 7404592.355)
# 3       POINT (329564.918 7404524.956)
# 4       POINT (338353.381 7408521.455)
# 5       POINT (329493.475 7404466.214)
# ...                                ...
# 664923  POINT (325550.459 7402150.515)
# 664938  POINT (333158.805 7387380.134)
# 664942  POINT (332494.788 7383932.063)
# 664969  POINT (330143.547 7381706.295)
# 664972  POINT (334113.883 7400586.689)
#
# [103788 rows x 19 columns]

# %%
pontos[pontos.Serviço.str.contains('Morcego')]
# Out:
# Empty GeoDataFrame
# Columns: [index, Data de abertura, Canal, Tema, Assunto, Serviço, Logradouro, Número, CEP, Subprefeitura, Distrito, Setor, Quadra, Latitude, Longitude, Data do parecer, Status da solicitação, Órgão, geometry]
# Index: []

# %%
gdf_servicos_pontos.index
# Out:
# Index(['(antigo) Reformar galerias de águas de chuvas (pluviais)',
#        'Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)',
#        'Avisar sobre animal agressor em vias públicas',
#        'Capinação em guias e sarjetas',
#        'Cata Bagulho - Reclamação de não retirada de material',
#        'Conserto de lixeira',
#        'Denúncia de má conduta dos funcionários (motoristas /coletores)',
#        'Denúncia de má conduta dos funcionários de limpeza',
#        'Fiscalização de veículo estacionado em local proibido',
#        'Implantação de coleta porta-porta',
#        'Instalação de contêiner para coleta de lixo domiciliar',
#        'Instalação de contêiner para coleta seletiva',
#        'Instalação e remoção de lixeira',
#        'Lavagem especial de locais públicos',
#        'Limpeza da via pública após enchentes ou eventos',
#        'Limpeza de bueiros, boca de lobo e poços de visita',
#        'Manutenção de placas de trânsito',
#        'Morcego - Reclamar sobre local com morcego',
#        'Pintura de guias e postes',
#        'Reclamação de falta de limpeza de ruas após a feira',
#        'Reclamação de falta de varrição',
#        'Reclamação de não remoção dos sacos de varrição',
#        'Reclamações sobre coleta de lixo domiciliar',
#        'Reclamações sobre coleta de resíduos de serviços de saúde',
#        'Reclamações sobre coleta seletiva',
#        'Sinalização horizontal apagada (pintura de solo)  Solicitar repintura',
#        'Sinalização horizontal apagada (pintura de solo) – Solicitar repintura',
#        'Solicitar avaliação de local com pernilongo/mosquito',
#        'Solicitar limpeza de bueiros, boca de lobo e poços de visita',
#        'Tapa-buraco', 'Tapa-buraco em faixa exclusiva ou corredor de ônibus',
#        'Vistoria de colmeia/vespeiro instalado',
#        'Ônibus - Denúncia de direção inadequada ou perigosa de veículo',
#        'Ônibus - Reclamação de intervalo excessivo da linha'],
#       dtype='object', name='Serviço')

# %%
pontos.Serviço.unique()
# Out:
# array(['Tapa-buraco',
#        'Ônibus - Reclamação de intervalo excessivo da linha',
#        'Fiscalização de veículo estacionado em local proibido',
#        'Instalação e remoção de lixeira',
#        'Reclamação de falta de varrição', 'Capinação em guias e sarjetas',
#        'Ônibus - Denúncia de direção inadequada ou perigosa de veículo',
#        'Limpeza de bueiros, boca de lobo e poços de visita',
#        'Lavagem especial de locais públicos',
#        'Cata Bagulho - Reclamação de não retirada de material',
#        'Pintura de guias e postes', 'Manutenção de placas de trânsito',
#        'Sinalização horizontal apagada (pintura de solo) \x96 Solicitar repintura',
#        'Limpeza da via pública após enchentes ou eventos',
#        'Reclamação de não remoção dos sacos de varrição',
#        'Instalação de contêiner para coleta seletiva',
#        'Instalação de contêiner para coleta de lixo domiciliar',
#        'Conserto de lixeira',
#        'Tapa-buraco em faixa exclusiva ou corredor de ônibus',
#        'Reclamação de falta de limpeza de ruas após a feira',
#        'Solicitar limpeza de bueiros, boca de lobo e poços de visita'],
#       dtype=object)

# %%
len(pontos)
# Out:
# 103788

# %%
# gdf[gdf.Serviço.isin(gdf_servicos_pontos.index) & gdf_sp.municipio.isna()].plot()

# %%
for t in pontos.Tema.unique():
    log.write(f"{t}: ({len(pontos[(pontos.Tema == t)])})\n")
    for s in pontos[(pontos.Tema == t)].Serviço.unique():
        log.write(f"  {s}: ({len(pontos[(pontos.Serviço == s) & (pontos.Tema == t)])})\n")
        r = pontos[(pontos.Serviço == s) & (pontos.Tema == t)]
        if len(r) > 1:
            r.to_file(f'resultados/Visualizador-156-2020.gpkg', layer=f'{t} - Ponto - {s}', driver='GPKG')

# %%
pontos_menor_200 = gdf_menor_200[gdf_menor_200.geometry.is_valid]

# %%
len(pontos_menor_200)
# Out:
# 598

# %%
log.write(f"Outros: ({len(pontos_menor_200)})\n")
pontos_menor_200.to_file(f'resultados/Visualizador-156-2020.gpkg', layer=f'Outros - Serviços com menos de {limite} ocorrências - Ponto', driver='GPKG')

# %% [markdown]
# ## Salvando LOG

# %%
log.write(f'- {datetime.now().strftime("%d/%m/%Y %H:%M:%S")}')
log.write('## Finalizando processamento')
# Out:
# 28

# %%
log.close()

# %%
# gdf
